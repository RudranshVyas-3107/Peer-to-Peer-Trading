# %%
import numpy as np
import tensorflow as tf
import statistics
from predicted_usage_pj import PredictedUsagePJ
from average_usage_pj import AverageUsagePJ
import math

# %%
class QNetwork(tf.keras.Model):
    def __init__(self, input_dim, output_dim, hidden_layer_sizes):
        super(QNetwork, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.hidden_layer_sizes = hidden_layer_sizes
        self.input_layer = tf.keras.layers.InputLayer(input_shape=(input_dim,))
        self.hidden_layers = [tf.keras.layers.Dense(size, activation='relu') for size in self.hidden_layer_sizes]
        self.output_layer = tf.keras.layers.Dense(output_dim, activation='linear')

    def call(self, inputs):
        x = self.input_layer(inputs)
        for layer in self.hidden_layers:
            x = layer(x)
        return self.output_layer(x)

# %%
def change_output_layer_and_retain_weights(base_model, num_neurons, optimizer, loss):
    # Save current weights except the output layer
    current_weights = [layer.get_weights() for layer in base_model.layers[:-1]]

    new_model = QNetwork(base_model.input_dim, num_neurons, base_model.hidden_layer_sizes)
    new_model.build((None, base_model.input_dim))  
    
    for layer, weights in zip(new_model.layers[:-1], current_weights):
        layer.set_weights(weights)

    new_model.compile(optimizer=optimizer, loss=loss)

    return new_model

# %%
def deep_q_learning_prosumer_agent(Q_network, epsilon_decay_rate, Pt_Hj, rho_t_b, rho_t_s, gamma_prosumer, iteration): 
    epsilon = max(0.01, 1 - iteration / epsilon_decay_rate)
        
    s_t_PAj = get_current_state_prosumer(iteration)
    q_values = Q_network.predict(np.array([s_t_PAj]))
    
    if q_values.size == 0:
        print("Warning: Q-values are empty. Defaulting to random action.")
        if Q_network.output_dim > 0:
            a_t = np.random.randint(Q_network.output_dim)
        else:
            print("Error: QNetwork output_dim is non-positive.")
            return None  
    if np.random.rand() < epsilon:
        a_t = np.random.randint(Q_network.output_dim)
    else:
        a_t = np.argmax(q_values)
            
    r_t_plus_1_PAj = get_reward_prosumer(Pt_Hj, rho_t_b, rho_t_s)
    s_t_plus_1_PAj = get_current_state_prosumer(iteration + 1)
            
    q_values_next = Q_network.predict(np.array([s_t_plus_1_PAj]))
    max_q_value = np.max(q_values_next)
            
    target = q_values
    target[0][a_t] = r_t_plus_1_PAj + gamma_prosumer * max_q_value
            
    Q_network.fit(np.array([s_t_PAj]), target, epochs=1, verbose=0)
    
    return a_t

# %%
def deep_q_learning_grid_agent(Q_network, epsilon_decay_rate, Pt_D, Pt_Gi, Pt_H_all, rho_t_s, gamma, iteration):
    epsilon = max(0.01, 1 - iteration / epsilon_decay_rate)
    
    s_t_GA = get_current_state_grid(iteration)
    q_values = Q_network.predict(np.array([s_t_GA]))
    print(q_values)
    if q_values.size == 0:
        print("Warning: Q-values are empty. Defaulting to random action.")
        if Q_network.output_dim > 0:
            a_t = np.random.randint(Q_network.output_dim)
        else:
            print("Error: QNetwork output_dim is non-positive.")
            return None  
    else:
        if np.random.rand() < epsilon:
            a_t = np.random.randint(Q_network.output_dim)
        else:
            a_t = np.argmax(q_values)
            
    r_t_plus_1_GA = get_reward_grid(Pt_D, Pt_Gi, Pt_H_all, rho_t_s)
    s_t_plus_1_GA = get_current_state_grid(iteration + 1)
            
    q_values_next = Q_network.predict(np.array([s_t_plus_1_GA]))
    max_q_value = np.max(q_values_next)
            
    target = q_values
    target[0][a_t] = r_t_plus_1_GA + gamma * max_q_value
            
    Q_network.fit(np.array([s_t_GA]), target, epochs=1, verbose=0)
    
    return a_t

# %%
def get_reward_grid(Pt_D, Pt_Gi, Pt_H_all, rho_t_s):
    
    vt_G = Pt_D * rho_t_s  
    grid_cost_generation = sum(Pt_Gi)
    grid_cost_prosumers = sum(Pt_H_all)
    rt_GA = vt_G - (grid_cost_generation + grid_cost_prosumers)
    
    return rt_GA

# %%
def get_reward_prosumer(Pt_Hj, rho_t_b, rho_t_s):
    
    vt_Hj = Pt_Hj * rho_t_b
    prosumer_cost = Pt_Hj * rho_t_s
    rt_PAj = vt_Hj - prosumer_cost
    
    return rt_PAj

# %%
market_price= np.random.rand(61)
def get_current_state_prosumer(i):
    
    current_state = [
        get_battery_state(i),  # how much our battery is charged at that moment
        get_pv_generation(i),   # how much power has been generated for the past minute/hour/or any scale
        market_price[i],  # current market price
    ]
    
    return current_state

# %%
import numpy as np
np.random.rand(10)
# Out:
# array([0.12253558, 0.38334959, 0.83184186, 0.26381137, 0.58120627,
#        0.8781816 , 0.80367028, 0.33893624, 0.92410852, 0.84237903])

# %%
def get_current_state_grid(i):
    current_state = [
        get_generation_costs(i),  # generation costs
        get_prosumer_costs(i),   # prosumer costs
        get_grid_demand(i)       # grid demand
    ]
    return current_state

# %%
def avg_current_market_price(data_mp):
    avg = statistics.mean(data_mp)
    return avg

# %%
def best_buy_sell_price(data_mp, a_t, output_dim):
    buy_sell_prices = {}
    variance = np.var(data_mp)
    cmp = avg_current_market_price(data_mp)
    
    increament=2*variance/(output_dim-1)
    price=cmp-variance
    
    for i in range(output_dim):
        buy_sell_prices[str(i)] = price
        price += increament 

    a_t_key = str(a_t)
    best_price = buy_sell_prices.get(a_t_key)  # Default to current market price if not found
#     if a_t not in range(variance):
#         print("a_t not in variance")
#     else:
#         print("The value of a_t is this ", a_t)
    return best_price, variance

# %%
size=61
values=np.random.rand(size,2).tolist()
def initialize_Pt_Gi(i):
    return values[i]

# %%
values=np.random.rand(size,2).tolist()
def initialize_Pt_Hj(i):
    return values[i]

# %%
def grid_buy_price(i):
    """ Returns the grid's buy price at a particular time t. """
    grid_buy_prices = [10.0, 9.5, 10.2, 11.0, 10.8, 11.5, 10.2, 10.9, 11.1,
                       10.0, 9.5, 10.2, 11.0, 10.8, 11.5, 10.2, 10.9, 11.1,
                       10.0, 9.5, 10.2, 11.0, 10.8, 11.5, 10.2, 10.9, 11.1,
                       10.0, 9.5, 10.2, 11.0, 10.8, 11.5, 10.2, 10.9, 11.1,
                       10.0, 9.5, 10.2, 11.0, 10.8, 11.5, 10.2, 10.9, 11.1,
                       10.0, 9.5, 10.2, 11.0, 10.8, 11.5, 10.2, 10.9, 11.1,
                       9.6, 10.1, 10.3, 10.7, 11.4, 10.9, 13]  # Added 6 new values
    return grid_buy_prices[i]

# %%
def get_battery_state(i):
    battery_states = np.random.rand(61)
    return battery_states[i]

# %%
def grid_sell_price(i):
    """ Returns the grid's sell price at a particular time t. """
    grid_sell_prices = [12.0, 12.5, 13.0, 12.8, 13.2, 12.7, 13.3, 12.9, 13.0,
                        12.0, 12.5, 13.0, 12.8, 13.2, 12.7, 13.3, 12.9, 13.0,
                        12.0, 12.5, 13.0, 12.8, 13.2, 12.7, 13.3, 12.9, 13.0,
                        12.0, 12.5, 13.0, 12.8, 13.2, 12.7, 13.3, 12.9, 13.0,
                        12.0, 12.5, 13.0, 12.8, 13.2, 12.7, 13.3, 12.9, 13.0,
                        12.0, 12.5, 13.0, 12.8, 13.2, 12.7, 13.3, 12.9, 13.0,
                        12.4, 13.1, 12.9, 13.3, 12.8, 13.0, 14] 
    return grid_sell_prices[i]

# %%
def grid_power(i):
    """ Returns the total power demanded from the grid at a particular time t. """
    grid_power_demand = [50, 48, 55, 60, 52, 58, 62, 56, 53,
                         50, 48, 55, 60, 52, 58, 62, 56, 53,
                         50, 48, 55, 60, 52, 58, 62, 56, 53,
                         50, 48, 55, 60, 52, 58, 62, 56, 53,
                         50, 48, 55, 60, 52, 58, 62, 56, 53,
                         50, 48, 55, 60, 52, 58, 62, 56, 53,
                         49, 47, 54, 59, 51, 57, 58]
    return grid_power_demand[i]

# %%
def Data(i):
    """ List of current market prices over a certain period of time decided by us. """
    market_prices = [10.5, 10.2, 11.0, 11.5, 10.8, 11.2, 11.3, 10.9, 11.1,
                     10.5, 10.2, 11.0, 11.5, 10.8, 11.2, 11.3, 10.9, 11.1,
                     10.5, 10.2, 11.0, 11.5, 10.8, 11.2, 11.3, 10.9, 11.1,
                     10.5, 10.2, 11.0, 11.5, 10.8, 11.2, 11.3, 10.9, 11.1,
                     10.5, 10.2, 11.0, 11.5, 10.8, 11.2, 11.3, 10.9, 11.1,
                     10.5, 10.2, 11.0, 11.5, 10.8, 11.2, 11.3, 10.9, 11.1,
                     10.7, 10.4, 10.9, 11.2, 10.9, 11.0, 12]
    return market_prices[i], market_prices

# %%
def jth_prosumer_power(i):
    """ Returns excess power generated by a prosumer. """
    prosumer_power_generation = [20, 22, 18, 25, 23, 19, 26, 21, 24,
                                 20, 22, 18, 25, 23, 19, 26, 21, 24,
                                 20, 22, 18, 25, 23, 19, 26, 21, 24,
                                 20, 22, 18, 25, 23, 19, 26, 21, 24,
                                 20, 22, 18, 25, 23, 19, 26, 21, 24,
                                 20, 22, 18, 25, 23, 19, 26, 21, 24,
                                 27, 22, 19, 24, 23, 20, 21] 
    return prosumer_power_generation[i]

# %%
def get_pv_generation(i):
    pv_generation_values = np.random.uniform(0, 30, 61)
    return pv_generation_values[i]

# %%
np.random
# Out:
# <module 'numpy.random' from 'C:\\Users\\SIDDHARTH SINGH\\anaconda3\\lib\\site-packages\\numpy\\random\\__init__.py'>

# %%
def get_generation_costs(i):
    """ Returns the generation cost at a specific time t. """
    generation_costs = [20, 22, 19, 24, 23, 25, 21, 18, 22, 23,
                        20, 22, 19, 24, 23, 25, 21, 18, 22, 23,
                        20, 22, 19, 24, 23, 25, 21, 18, 22, 23,
                        20, 22, 19, 24, 23, 25, 21, 18, 22, 23,
                        20, 22, 19, 24, 23, 25, 21, 18, 22, 23,
                        20, 22, 19, 24, 23, 25, 21, 18, 22, 23,
                        20, 19, 24, 25, 22, 21, 22]
    return generation_costs[i]

# %%
def get_prosumer_costs(i):
    """ Returns the prosumer cost at a specific time t. """
    prosumer_costs = [30, 28, 35, 32, 33, 31, 29, 34, 30,
                      30, 28, 35, 32, 33, 31, 29, 34, 30,
                      30, 28, 35, 32, 33, 31, 29, 34, 30,
                      30, 28, 35, 32, 33, 31, 29, 34, 30,
                      30, 28, 35, 32, 33, 31, 29, 34, 30,
                      30, 28, 35, 32, 33, 31, 29, 34, 30,
                      32, 29, 33, 30, 31, 32, 33]  
    return prosumer_costs[i]

# %%
def get_grid_demand(i):
    """ Returns the grid demand at a specific time t. """
    grid_demand = [40, 45, 42, 50, 48, 46, 44, 43, 47,
                   40, 45, 42, 50, 48, 46, 44, 43, 47,
                   40, 45, 42, 50, 48, 46, 44, 43, 47,
                   40, 45, 42, 50, 48, 46, 44, 43, 47,
                   40, 45, 42, 50, 48, 46, 44, 43, 47,
                   40, 45, 42, 50, 48, 46, 44, 43, 47,
                   41, 44, 42, 51, 49, 46, 47] 
    return grid_demand[i]

# %%
timestamps = np.arange(61)  # Assuming 60 samples
battery_states = np.random.rand(61)  # Random battery states for each sample
pv_generation = np.random.rand(61)  # Random PV generation for each sample
market_prices = np.random.rand(61)  # Random market prices for each sample
energy_values = np.random.rand(61)  # Random energy values for each sample

# Stack the features into X_train
X_train = np.column_stack((timestamps, battery_states, pv_generation, market_prices))

# Set up y_train as the energy values
y_train = energy_values

# %%
max_iteration = 60
input_dim = 3 
epsilon_decay_rate=0.01
predicted_pj = PredictedUsagePJ()
average_usage_pj = AverageUsagePJ()
hidden_layer_sizes = [64, 128, 64] 
prosumer_number=2
output_dim_prosumer=5
output_dim_grid=5
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
gamma=0.3
gamma_prosumer=0.3

q_network_grid = QNetwork(input_dim, output_dim_grid, hidden_layer_sizes)
q_network_grid.compile(optimizer='adam', loss='mean_squared_error')

# q_network_prosumer = QNetwork(input_dim, output_dim_prosumer, hidden_layer_sizes)
# q_network_prosumer.compile(optimizer=optimizer, loss='mean_squared_error')

network_prosumers = [QNetwork(input_dim, output_dim_prosumer, hidden_layer_sizes) for _ in range(prosumer_number)]
for net in network_prosumers:
    net.compile(optimizer='adam', loss='mean_squared_error')

for iteration in range(max_iteration):

    Pt_D = grid_power(iteration)
    rho_t_s = grid_sell_price(iteration)
    Pt_H_all = initialize_Pt_Hj(iteration)
    Pt_Gi = initialize_Pt_Gi(iteration)
    
    if iteration >= 5:
        data_mp = market_prices[iteration - 4:iteration + 1]
    else:
        data_mp=market_prices[:iteration+5]
        
    a_t_grid = deep_q_learning_grid_agent(q_network_grid, epsilon_decay_rate, Pt_D, Pt_Gi, Pt_H_all, rho_t_s, gamma,iteration)
    rho_t_b = grid_buy_price(iteration)
    best_sell_price, variance = best_buy_sell_price(data_mp, a_t_grid, output_dim_grid)
    print(f"Iteration:{iteration}, For grid agent best sell price is: {best_sell_price}")
    
    for j in range(prosumer_number):
        
        data, market_prices = Data(iteration)
        Pt_Hj = initialize_Pt_Hj(iteration)[j]  
            
        a_t_prosumer = deep_q_learning_prosumer_agent(network_prosumers[j], epsilon_decay_rate, Pt_Hj, rho_t_b, rho_t_s, gamma_prosumer,iteration)

        x = X_train[iteration].reshape(1, -1) 
        y = np.array([y_train[iteration]])    

        predicted_pj.train_model(x, y)
        predicted_usage_pj = predicted_pj.predict_usage(X_train[iteration])

        average_usage_pj.update_usage(y_train[iteration])
        average_usage = average_usage_pj.calculate_average_usage()

        if predicted_usage_pj > average_usage:    
            best_buy_price, variance = best_buy_sell_price(data_mp, a_t_prosumer, output_dim_prosumer)
            print(f"Iteration: {iteration}, For agent: {j}, best buy price is: {best_buy_price}")
        else:
            best_sell_price, variance = best_buy_sell_price(data_mp, a_t_prosumer, output_dim_prosumer)
            print(f"Iteration: {iteration}, For agent: {j}, best sell price is: {best_sell_price}")
# Out:
# 1/1 [==============================] - 0s 288ms/step
# [[-8.436445   1.2933575 -1.6028746 -7.319366   1.4889235]]
# 1/1 [==============================] - 0s 22ms/step
# Iteration:0, For grid agent best sell price is: 0.5166837184187364
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 22ms/step
# Iteration: 0, For agent: 0, best sell price is: 0.3005340186744069
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 23ms/step
# Iteration: 0, For agent: 1, best sell price is: 0.40860886854657164
# 1/1 [==============================] - 0s 20ms/step
# [[-7.741612    0.76462555 -1.1157223  -7.991831    4.321465  ]]
# 1/1 [==============================] - 0s 22ms/step
# Iteration:1, For grid agent best sell price is: 11.052222222222223
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# Iteration: 1, For agent: 0, best sell price is: 10.773888888888889
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# Iteration: 1, For agent: 1, best sell price is: 10.866666666666667
# 1/1 [==============================] - 0s 18ms/step
# [[-7.8511786   0.36400756 -0.48809874 -8.345779    7.671534  ]]
# 1/1 [==============================] - 0s 20ms/step
# Iteration:2, For grid agent best sell price is: 11.11061224489796
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# Iteration: 2, For agent: 0, best sell price is: 10.837551020408164
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# Iteration: 2, For agent: 1, best sell price is: 11.11061224489796
# 1/1 [==============================] - 0s 21ms/step
# [[-6.9726872   0.15321892  0.9188083  -9.2629175  11.802825  ]]
# 1/1 [==============================] - 0s 20ms/step
# Iteration:3, For grid agent best sell price is: 11.084375000000001
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# Iteration: 3, For agent: 0, best sell price is: 10.8453125
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# Iteration: 3, For agent: 1, best sell price is: 10.765625
# 1/1 [==============================] - 0s 21ms/step
# [[-6.349291  -0.3328038  1.8101505 -9.354551  14.757145 ]]
# 1/1 [==============================] - 0s 28ms/step
# Iteration:4, For grid agent best sell price is: 11.089135802469135
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# Iteration: 4, For agent: 0, best sell price is: 10.799753086419754
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteration: 4, For agent: 1, best sell price is: 10.799753086419754
# 1/1 [==============================] - 0s 20ms/step
# [[-5.487612  -0.7608258  2.6633124 -9.5699625 17.535849 ]]
# 1/1 [==============================] - 0s 24ms/step
# Iteration:5, For grid agent best sell price is: 11.1304
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# Iteration: 5, For agent: 0, best sell price is: 10.7496
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteration: 5, For agent: 1, best sell price is: 10.7496
# 1/1 [==============================] - 0s 30ms/step
# [[-4.5871916 -1.5560673  3.1204467 -8.952409  18.933348 ]]
# 1/1 [==============================] - 0s 26ms/step
# Iteration:6, For grid agent best sell price is: 11.218399999999997
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Iteration: 6, For agent: 0, best sell price is: 11.1016
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteration: 6, For agent: 1, best sell price is: 11.189199999999998
# 1/1 [==============================] - 0s 33ms/step
# [[-4.7534685 -2.7788835  3.6054854 -9.302667  21.581087 ]]
# 1/1 [==============================] - 0s 26ms/step
# Iteration:7, For grid agent best sell price is: 11.206400000000004
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# Iteration: 7, For agent: 0, best sell price is: 11.0736
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# Iteration: 7, For agent: 1, best sell price is: 11.106800000000002
# 1/1 [==============================] - 0s 24ms/step
# [[-3.8608549 -3.0877132  4.7947125 -9.862347  26.018927 ]]
# 1/1 [==============================] - 0s 33ms/step
# Iteration:8, For grid agent best sell price is: 11.094400000000004
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# Iteration: 8, For agent: 0, best sell price is: 11.042800000000002
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteration: 8, For agent: 1, best sell price is: 11.042800000000002
# 1/1 [==============================] - 0s 38ms/step
# [[-3.6649141 -3.666678   5.306712  -9.890949  27.148624 ]]
# 1/1 [==============================] - 0s 39ms/step
# Iteration:9, For grid agent best sell price is: 11.079999999999997
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step
# Iteration: 9, For agent: 0, best sell price is: 10.959999999999999
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# Iteration: 9, For agent: 1, best sell price is: 10.959999999999999
# 1/1 [==============================] - 0s 25ms/step
# [[-2.7278228 -4.3096223  6.1309857 -9.695738  30.535666 ]]
# 1/1 [==============================] - 0s 24ms/step
# Iteration:10, For grid agent best sell price is: 10.96
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# Iteration: 10, For agent: 0, best sell price is: 10.64
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 56ms/step
# Iteration: 10, For agent: 1, best sell price is: 10.72
# 1/1 [==============================] - 0s 23ms/step
# [[ -3.3622305  -5.4202056   7.3523397 -11.079717   35.094486 ]]
# 1/1 [==============================] - 0s 21ms/step
# Iteration:11, For grid agent best sell price is: 10.8544
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# Iteration: 11, For agent: 0, best sell price is: 10.6828
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# Iteration: 11, For agent: 1, best sell price is: 10.8544
# 1/1 [==============================] - 0s 21ms/step
# [[ -2.232593  -6.082609   8.547725 -11.025371  40.07316 ]]
# 1/1 [==============================] - 0s 21ms/step
# Iteration:12, For grid agent best sell price is: 11.0704
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteration: 12, For agent: 0, best sell price is: 10.7548
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Iteration: 12, For agent: 1, best sell price is: 10.7548
# 1/1 [==============================] - 0s 19ms/step
# [[ -2.3381207  -6.9010196  10.098419  -12.337278   45.437626 ]]
# 1/1 [==============================] - 0s 21ms/step
# Iteration:13, For grid agent best sell price is: 10.996000000000004
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteration: 13, For agent: 0, best sell price is: 10.702000000000002
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# Iteration: 13, For agent: 1, best sell price is: 10.996000000000004
# 1/1 [==============================] - 0s 19ms/step
# [[ -2.0841706  -7.086363   10.70997   -12.301511   47.129128 ]]
# 1/1 [==============================] - 0s 22ms/step
# Iteration:14, For grid agent best sell price is: 11.1304
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteration: 14, For agent: 0, best sell price is: 10.8448
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# Iteration: 14, For agent: 1, best sell price is: 10.8448
# 1/1 [==============================] - 0s 21ms/step
# [[ -1.901593  -7.557908  11.702095 -12.837194  50.35918 ]]
# 1/1 [==============================] - 0s 20ms/step
# Iteration:15, For grid agent best sell price is: 11.218399999999997
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# Iteration: 15, For agent: 0, best sell price is: 11.130799999999999
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# Iteration: 15, For agent: 1, best sell price is: 11.130799999999999
# 1/1 [==============================] - 0s 23ms/step
# [[ -2.5232143  -8.042102   12.133645  -13.602342   53.15344  ]]
# 1/1 [==============================] - 0s 18ms/step
# Iteration:16, For grid agent best sell price is: 11.206400000000004
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Iteration: 16, For agent: 0, best sell price is: 11.106800000000002
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteration: 16, For agent: 1, best sell price is: 11.0736
# 1/1 [==============================] - 0s 21ms/step
# [[ -2.1224926  -8.664468   12.869623  -13.815459   56.400566 ]]
# 1/1 [==============================] - 0s 25ms/step
# Iteration:17, For grid agent best sell price is: 11.094400000000004
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# Iteration: 17, For agent: 0, best sell price is: 11.042800000000002
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Iteration: 17, For agent: 1, best sell price is: 11.0256
# 1/1 [==============================] - 0s 23ms/step
# [[ -2.3974462  -9.077213   13.636711  -14.445521   58.53305  ]]
# 1/1 [==============================] - 0s 22ms/step
# Iteration:18, For grid agent best sell price is: 11.079999999999997
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# Iteration: 18, For agent: 0, best sell price is: 10.959999999999999
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# Iteration: 18, For agent: 1, best sell price is: 10.92
# 1/1 [==============================] - 0s 19ms/step
# [[ -2.3824904 -10.5651865  15.622968  -16.009056   66.67762  ]]
# 1/1 [==============================] - 0s 21ms/step
# Iteration:19, For grid agent best sell price is: 10.96
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Iteration: 19, For agent: 0, best sell price is: 10.72
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# Iteration: 19, For agent: 1, best sell price is: 10.64
# 1/1 [==============================] - 0s 27ms/step
# [[ -3.4655035 -11.356396   16.172     -16.891052   69.85011  ]]
# 1/1 [==============================] - 0s 23ms/step
# Iteration:20, For grid agent best sell price is: 10.8544
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteration: 20, For agent: 0, best sell price is: 10.6828
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteration: 20, For agent: 1, best sell price is: 10.6256
# 1/1 [==============================] - 0s 22ms/step
# [[ -3.3749657 -13.540653   19.422667  -19.462132   82.42945  ]]
# 1/1 [==============================] - 0s 19ms/step
# Iteration:21, For grid agent best sell price is: 11.0704
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# Iteration: 21, For agent: 0, best sell price is: 10.7548
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# Iteration: 21, For agent: 1, best sell price is: 10.6496
# 1/1 [==============================] - 0s 20ms/step
# [[ -3.8949957 -13.99128    19.942053  -19.870108   84.0118   ]]
# 1/1 [==============================] - 0s 21ms/step
# Iteration:22, For grid agent best sell price is: 10.996000000000004
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# Iteration: 22, For agent: 0, best sell price is: 10.702000000000002
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Iteration: 22, For agent: 1, best sell price is: 10.604000000000001
# 1/1 [==============================] - 0s 34ms/step
# [[ -4.150751 -15.315545  22.15047  -21.694155  91.766556]]
# 1/1 [==============================] - 0s 26ms/step
# Iteration:23, For grid agent best sell price is: 11.1304
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteration: 23, For agent: 0, best sell price is: 10.8448
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Iteration: 23, For agent: 1, best sell price is: 10.7496
# 1/1 [==============================] - 0s 22ms/step
# [[ -4.3967085 -15.792154   22.770004  -22.00769    93.58925  ]]
# 1/1 [==============================] - 0s 29ms/step
# Iteration:24, For grid agent best sell price is: 11.218399999999997
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# Iteration: 24, For agent: 0, best sell price is: 11.130799999999999
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# Iteration: 24, For agent: 1, best sell price is: 11.1016
# 1/1 [==============================] - 0s 24ms/step
# [[ -5.517185 -17.665283  25.684114 -24.78653  104.71411 ]]
# 1/1 [==============================] - 0s 28ms/step
# Iteration:25, For grid agent best sell price is: 11.206400000000004
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# Iteration: 25, For agent: 0, best sell price is: 11.106800000000002
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# Iteration: 25, For agent: 1, best sell price is: 11.0736
# 1/1 [==============================] - 0s 22ms/step
# [[ -5.697221 -18.867756  26.790665 -25.375986 109.1912  ]]
# 1/1 [==============================] - 0s 24ms/step
# Iteration:26, For grid agent best sell price is: 11.094400000000004
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# Iteration: 26, For agent: 0, best sell price is: 11.042800000000002
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Iteration: 26, For agent: 1, best sell price is: 11.0256
# 1/1 [==============================] - 0s 25ms/step
# [[ -5.975583 -17.88425   25.407843 -24.028751 103.08142 ]]
# 1/1 [==============================] - 0s 27ms/step
# Iteration:27, For grid agent best sell price is: 11.079999999999997
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# Iteration: 27, For agent: 0, best sell price is: 10.959999999999999
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# Iteration: 27, For agent: 1, best sell price is: 10.92
# 1/1 [==============================] - 0s 27ms/step
# [[ -6.8181157 -21.32296    30.147858  -27.982927  121.41537  ]]
# 1/1 [==============================] - 0s 24ms/step
# Iteration:28, For grid agent best sell price is: 10.96
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# Iteration: 28, For agent: 0, best sell price is: 10.96
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# Iteration: 28, For agent: 1, best sell price is: 10.64
# 1/1 [==============================] - 0s 27ms/step
# [[ -8.368884 -23.163921  33.00623  -30.734205 132.34364 ]]
# 1/1 [==============================] - 0s 24ms/step
# Iteration:29, For grid agent best sell price is: 10.8544
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# Iteration: 29, For agent: 0, best sell price is: 10.8544
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Iteration: 29, For agent: 1, best sell price is: 10.6256
# 1/1 [==============================] - 0s 24ms/step
# [[ -9.1427145 -26.254316   36.56474   -33.51808   146.86731  ]]
# 1/1 [==============================] - 0s 25ms/step
# Iteration:30, For grid agent best sell price is: 11.0704
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Iteration: 30, For agent: 0, best sell price is: 11.0704
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteration: 30, For agent: 1, best sell price is: 10.6496
# 1/1 [==============================] - 0s 22ms/step
# [[-10.210993 -28.200096  39.37211  -35.913803 157.47621 ]]
# 1/1 [==============================] - 0s 21ms/step
# Iteration:31, For grid agent best sell price is: 10.996000000000004
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# Iteration: 31, For agent: 0, best sell price is: 10.996000000000004
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteration: 31, For agent: 1, best sell price is: 10.604000000000001
# 1/1 [==============================] - 0s 42ms/step
# [[-10.494846 -28.245626  39.102936 -35.421772 156.39534 ]]
# 1/1 [==============================] - 0s 37ms/step
# Iteration:32, For grid agent best sell price is: 11.1304
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# Iteration: 32, For agent: 0, best sell price is: 11.1304
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteration: 32, For agent: 1, best sell price is: 11.0352
# 1/1 [==============================] - 0s 21ms/step
# [[-11.520044 -30.761154  42.751072 -38.392323 170.06903 ]]
# 1/1 [==============================] - 0s 22ms/step
# Iteration:33, For grid agent best sell price is: 11.218399999999997
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Iteration: 33, For agent: 0, best sell price is: 11.218399999999997
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteration: 33, For agent: 1, best sell price is: 11.189199999999998
# 1/1 [==============================] - 0s 21ms/step
# [[-13.201887 -33.166183  46.00794  -41.34005  183.1318  ]]
# 1/1 [==============================] - 0s 22ms/step
# Iteration:34, For grid agent best sell price is: 11.206400000000004
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# Iteration: 34, For agent: 0, best sell price is: 11.206400000000004
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Iteration: 34, For agent: 1, best sell price is: 11.173200000000003
# 1/1 [==============================] - 0s 25ms/step
# [[-14.576459 -37.219303  51.148678 -45.38098  203.48592 ]]
# 1/1 [==============================] - 0s 23ms/step
# Iteration:35, For grid agent best sell price is: 11.094400000000004
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteration: 35, For agent: 0, best sell price is: 11.094400000000004
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# Iteration: 35, For agent: 1, best sell price is: 11.077200000000003
# 1/1 [==============================] - 0s 20ms/step
# [[-14.317254 -34.803356  47.735897 -42.34511  190.1281  ]]
# 1/1 [==============================] - 0s 21ms/step
# Iteration:36, For grid agent best sell price is: 11.079999999999997
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Iteration: 36, For agent: 0, best sell price is: 11.079999999999997
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# Iteration: 36, For agent: 1, best sell price is: 11.039999999999997
# 1/1 [==============================] - 0s 23ms/step
# [[-15.580885 -37.87912   51.217564 -45.01495  204.7006  ]]
# 1/1 [==============================] - 0s 25ms/step
# Iteration:37, For grid agent best sell price is: 10.96
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# Iteration: 37, For agent: 0, best sell price is: 10.96
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Iteration: 37, For agent: 1, best sell price is: 10.88
# 1/1 [==============================] - 0s 28ms/step
# [[-18.421314 -42.432846  57.810734 -50.94449  230.75867 ]]
# 1/1 [==============================] - 0s 22ms/step
# Iteration:38, For grid agent best sell price is: 10.8544
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 22ms/step
# Iteration: 38, For agent: 0, best sell price is: 10.8544
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# Iteration: 38, For agent: 1, best sell price is: 10.7972
# 1/1 [==============================] - 0s 35ms/step
# [[-21.15776  -49.39644   66.550064 -58.001827 266.20166 ]]
# 1/1 [==============================] - 0s 30ms/step
# Iteration:39, For grid agent best sell price is: 11.0704
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# Iteration: 39, For agent: 0, best sell price is: 11.0704
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# Iteration: 39, For agent: 1, best sell price is: 10.9652
# 1/1 [==============================] - 0s 30ms/step
# [[-22.079712 -50.0653    67.16096  -58.42179  269.3967  ]]
# 1/1 [==============================] - 0s 26ms/step
# Iteration:40, For grid agent best sell price is: 10.996000000000004
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Iteration: 40, For agent: 0, best sell price is: 10.996000000000004
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# Iteration: 40, For agent: 1, best sell price is: 10.898000000000003
# 1/1 [==============================] - 0s 34ms/step
# [[-23.401169 -52.400063  70.22353  -60.79343  281.8586  ]]
# 1/1 [==============================] - 0s 26ms/step
# Iteration:41, For grid agent best sell price is: 11.1304
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# Iteration: 41, For agent: 0, best sell price is: 11.1304
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# Iteration: 41, For agent: 1, best sell price is: 11.0352
# 1/1 [==============================] - 0s 66ms/step
# [[-23.52578  -51.806507  69.06062  -59.5597   278.05835 ]]
# 1/1 [==============================] - 0s 24ms/step
# Iteration:42, For grid agent best sell price is: 11.218399999999997
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# Iteration: 42, For agent: 0, best sell price is: 11.218399999999997
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# Iteration: 42, For agent: 1, best sell price is: 11.189199999999998
# 1/1 [==============================] - 0s 24ms/step
# [[-27.747095 -59.349068  79.413704 -68.46275  319.97464 ]]
# 1/1 [==============================] - 0s 25ms/step
# Iteration:43, For grid agent best sell price is: 11.206400000000004
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# Iteration: 43, For agent: 0, best sell price is: 11.206400000000004
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# Iteration: 43, For agent: 1, best sell price is: 11.173200000000003
# 1/1 [==============================] - 0s 28ms/step
# [[-29.771694 -63.746384  84.6304   -72.43839  342.19763 ]]
# 1/1 [==============================] - 0s 36ms/step
# Iteration:44, For grid agent best sell price is: 11.094400000000004
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# Iteration: 44, For agent: 0, best sell price is: 11.094400000000004
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# Iteration: 44, For agent: 1, best sell price is: 11.077200000000003
# 1/1 [==============================] - 0s 21ms/step
# [[-30.309216 -63.33288   84.34333  -72.13735  341.50046 ]]
# 1/1 [==============================] - 0s 32ms/step
# Iteration:45, For grid agent best sell price is: 11.079999999999997
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Iteration: 45, For agent: 0, best sell price is: 11.079999999999997
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Iteration: 45, For agent: 1, best sell price is: 11.039999999999997
# 1/1 [==============================] - 0s 31ms/step
# [[-32.36068  -67.298676  88.8135   -75.55609  361.43985 ]]
# 1/1 [==============================] - 0s 24ms/step
# Iteration:46, For grid agent best sell price is: 10.96
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# Iteration: 46, For agent: 0, best sell price is: 10.96
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 22ms/step
# Iteration: 46, For agent: 1, best sell price is: 10.88
# 1/1 [==============================] - 0s 26ms/step
# [[-34.582863 -69.36266   91.54199  -78.09067  374.12622 ]]
# 1/1 [==============================] - 0s 28ms/step
# Iteration:47, For grid agent best sell price is: 10.8544
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 42ms/step
# Iteration: 47, For agent: 0, best sell price is: 10.8544
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# Iteration: 47, For agent: 1, best sell price is: 10.7972
# 1/1 [==============================] - 0s 31ms/step
# [[-40.913498 -82.55396  108.44209  -91.835785 444.4366  ]]
# 1/1 [==============================] - 0s 39ms/step
# Iteration:48, For grid agent best sell price is: 11.0704
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# Iteration: 48, For agent: 0, best sell price is: 11.0704
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 22ms/step
# Iteration: 48, For agent: 1, best sell price is: 10.9652
# 1/1 [==============================] - 0s 58ms/step
# [[-43.607643 -86.53492  113.65621  -96.10771  467.28394 ]]
# 1/1 [==============================] - 0s 53ms/step
# Iteration:49, For grid agent best sell price is: 10.996000000000004
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 40ms/step
# Iteration: 49, For agent: 0, best sell price is: 10.996000000000004
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# Iteration: 49, For agent: 1, best sell price is: 10.898000000000003
# 1/1 [==============================] - 0s 18ms/step
# [[-43.42411 -85.12867 111.4636  -94.02408 460.22443]]
# 1/1 [==============================] - 0s 19ms/step
# Iteration:50, For grid agent best sell price is: 11.1304
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# Iteration: 50, For agent: 0, best sell price is: 11.1304
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# Iteration: 50, For agent: 1, best sell price is: 11.0352
# 1/1 [==============================] - 0s 18ms/step
# [[-45.42815  -88.19627  115.451584 -97.11743  478.1386  ]]
# 1/1 [==============================] - 0s 20ms/step
# Iteration:51, For grid agent best sell price is: 11.218399999999997
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# Iteration: 51, For agent: 0, best sell price is: 11.218399999999997
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Iteration: 51, For agent: 1, best sell price is: 11.189199999999998
# 1/1 [==============================] - 0s 20ms/step
# [[ -48.38363  -91.85688  120.08499 -101.07894  499.79968]]
# 1/1 [==============================] - 0s 25ms/step
# Iteration:52, For grid agent best sell price is: 11.206400000000004
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Iteration: 52, For agent: 0, best sell price is: 11.206400000000004
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# Iteration: 52, For agent: 1, best sell price is: 11.173200000000003
# 1/1 [==============================] - 0s 25ms/step
# [[ -54.838356 -104.17878   135.94855  -113.844925  567.60077 ]]
# 1/1 [==============================] - 0s 24ms/step
# Iteration:53, For grid agent best sell price is: 11.094400000000004
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# Iteration: 53, For agent: 0, best sell price is: 11.094400000000004
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteration: 53, For agent: 1, best sell price is: 11.077200000000003
# 1/1 [==============================] - 0s 19ms/step
# [[ -54.804337 -102.1378    133.42828  -111.773964  559.3038  ]]
# 1/1 [==============================] - 0s 20ms/step
# Iteration:54, For grid agent best sell price is: 11.086399999999996
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# Iteration: 54, For agent: 0, best sell price is: 11.086399999999996
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteration: 54, For agent: 1, best sell price is: 11.063199999999997
# 1/1 [==============================] - 0s 24ms/step
# [[ -59.792564 -111.13011   144.83878  -120.872375  609.49817 ]]
# 1/1 [==============================] - 0s 20ms/step
# Iteration:55, For grid agent best sell price is: 10.9776
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteration: 55, For agent: 0, best sell price is: 10.9288
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# Iteration: 55, For agent: 1, best sell price is: 10.9288
# 1/1 [==============================] - 0s 21ms/step
# [[ -61.126953 -111.6328    145.33514  -121.34725   614.5954  ]]
# 1/1 [==============================] - 0s 21ms/step
# Iteration:56, For grid agent best sell price is: 10.856000000000003
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# Iteration: 56, For agent: 0, best sell price is: 10.828000000000003
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteration: 56, For agent: 1, best sell price is: 10.828000000000003
# 1/1 [==============================] - 0s 26ms/step
# [[ -67.382515 -123.033745  159.37352  -132.48311   677.36694 ]]
# 1/1 [==============================] - 0s 19ms/step
# Iteration:57, For grid agent best sell price is: 10.9424
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# Iteration: 57, For agent: 0, best sell price is: 10.9012
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# Iteration: 57, For agent: 1, best sell price is: 10.9012
# 1/1 [==============================] - 0s 29ms/step
# [[ -73.015045 -131.9639    171.07361  -142.06609   729.63525 ]]
# 1/1 [==============================] - 0s 20ms/step
# Iteration:58, For grid agent best sell price is: 10.889600000000003
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# Iteration: 58, For agent: 0, best sell price is: 10.854800000000003
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# Iteration: 58, For agent: 1, best sell price is: 10.820000000000002
# 1/1 [==============================] - 0s 27ms/step
# [[ -75.65433 -135.19997  175.38782 -145.5498   750.8444 ]]
# 1/1 [==============================] - 0s 36ms/step
# Iteration:59, For grid agent best sell price is: 10.949600000000004
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 55ms/step
# Iteration: 59, For agent: 0, best sell price is: 10.914800000000003
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# Iteration: 59, For agent: 1, best sell price is: 10.880000000000003
